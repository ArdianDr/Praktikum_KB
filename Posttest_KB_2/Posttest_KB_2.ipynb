# %% [markdown]
# ## POSTTEST 2

# %% [markdown]
# ### 1. Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
import pandas as pd
import numpy as np

fifa = pd.read_csv('Fifa 23 Players Data.csv')
fifa.describe()
# Out:
#             Overall     Potential  Value(in Euro)           Age  \
# count  18539.000000  18539.000000    1.853900e+04  18539.000000
# mean      65.852042     71.016668    2.875461e+06     25.240412
# std        6.788353      6.192866    7.635129e+06      4.718163
# min       47.000000     48.000000    0.000000e+00     16.000000
# 25%       62.000000     67.000000    4.750000e+05     21.000000
# 50%       66.000000     71.000000    1.000000e+06     25.000000
# 75%       70.000000     75.000000    2.000000e+06     29.000000
# max       91.000000     95.000000    1.905000e+08     44.000000
#
#        Height(in cm)  Weight(in kg)    TotalStats     BaseStats  \
# count   18539.000000   18539.000000  18539.000000  18539.000000
# mean      181.550839      75.173904   1602.114569    357.946221
# std         6.858097       7.013593    273.160237     39.628259
# min       155.000000      49.000000    759.000000    224.000000
# 25%       177.000000      70.000000   1470.000000    331.000000
# ...

# %% [markdown]
# ### 2. Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
fifa = fifa.select_dtypes(["float","int"])
fifa.head(10)
# Out:
#    Overall  Potential  Value(in Euro)  Age  Height(in cm)  Weight(in kg)  \
# 0       91         91        54000000   35            169             67
# 1       91         91        64000000   34            185             81
# 2       91         91        84000000   33            185             81
# 3       91         91       107500000   31            181             70
# 4       91         95       190500000   23            182             73
# 5       90         90       115500000   30            175             71
# 6       90         91        90000000   30            199             96
# 7       90         90        13500000   36            193             93
# 8       90         90        41000000   37            187             83
# 9       90         90        98000000   30            193             92
#
#    TotalStats  BaseStats  Wage(in Euro)  Release Clause  ...  LM Rating  \
# 0        2190        452         195000        99900000  ...         91
# ...

# %% [markdown]
# ### 3. Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

# %%
fifa = pd.read_csv('Fifa 23 Players Data.csv')
record = fifa.shape[0]
atribut = fifa.columns
objek = fifa.select_dtypes(include=object).columns
angka = fifa.select_dtypes(include=np.number).columns
Null = fifa.loc[:, fifa.isna().any()].columns

# %%
info = {
    'jumlah_record': record,
    'nama_atribut': atribut,
    'atribut_object': objek,
    'atribut_angka': angka,
}

print("Jumlah Record\t\t\t\t:", info['jumlah_record'])

print("="*50)
print("Jumlah Atribut\t\t\t\t:", len(info['nama_atribut']))
print("="*50)
print("No\t| Nama Atribut")
print("-"*25)
for i, atribut in enumerate(info['nama_atribut']):
    print(f"{i}\t| {atribut}")

print("\n"+"="*50)
print("Jumlah Atribut dengan Tipe Objek\t:", len(info['atribut_object']))
print("="*50)
print("No\t| Atribut Tipe Object")
print("-"*30)
for i, objek in enumerate(info['atribut_object']):
    print(f"{i}\t| {objek}")

print("\n"+"="*50)
print("Jumlah Atribut dengan Tipe Angka\t:", len(info['atribut_angka']))
print("="*50)
print("No\t| Atribut Tipe Angka")
print("-"*30)
for i, angka in enumerate(info['atribut_angka']):
    print(f"{i}\t| {angka}")
# Out:
# Jumlah Record				: 18539
# ...
# Jumlah Atribut				: 89
# ...
# No	| Nama Atribut
# -------------------------
# 0	| Known As
# 1	| Full Name
# 2	| Overall
# 3	| Potential
# 4	| Value(in Euro)
# 5	| Positions Played
# 6	| Best Position
# 7	| Nationality
# 8	| Image Link
# 9	| Age
# 10	| Height(in cm)
# 11	| Weight(in kg)
# 12	| TotalStats
# 13	| BaseStats
# 14	| Club Name
# 15	| Wage(in Euro)
# 16	| Release Clause
# 17	| Club Position
# 18	| Contract Until
# 19	| Club Jersey Number
# 20	| Joined On
# 21	| On Loan
# 22	| Preferred Foot
# 23	| Weak Foot Rating
# 24	| Skill Moves
# 25	| International Reputation
# 26	| National Team Name
# 27	| National Team Image Link
# 28	| National Team Position
# 29	| National Team Jersey Number
# 30	| Attacking Work Rate
# 31	| Defensive Work Rate
# 32	| Pace Total
# 33	| Shooting Total
# 34	| Passing Total
# 35	| Dribbling Total
# 36	| Defending Total
# 37	| Physicality Total
# 38	| Crossing
# 39	| Finishing
# 40	| Heading Accuracy
# 41	| Short Passing
# ...

# %% [markdown]
# ### 4.Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice.

# %%
metode1 = fifa[130:].iloc[:, 3:]
metode1
# Out:
#        Potential  Value(in Euro) Positions Played Best Position  \
# 130           86        52500000           CM,CDM            CM
# 131           90        62500000           CDM,CM           CDM
# 132           87        56000000            LW,LM            RM
# 133           89        57500000               CB            CB
# 134           90        66000000            CM,RW            CM
# ...          ...             ...              ...           ...
# 18534         56          110000            ST,RM           CAM
# 18535         57           90000              CDM           CDM
# 18536         67          130000               CM            RM
# 18537         61          100000               CB            CB
# 18538         50           60000               LB            LB
#
#                Nationality                                        Image Link  \
# 130                Belgium  https://cdn.sofifa.net/players/216/393/23_60.png
# ...

# %%
metode2 = fifa.loc[130:, "Age":]
metode2
# Out:
#        Age  Height(in cm)  Weight(in kg)  TotalStats  BaseStats  \
# 130     25            176             72        2187        446
# 131     22            181             79        2225        475
# 132     25            180             73        2049        440
# 133     24            186             78        2043        445
# 134     23            182             78        2192        478
# ...    ...            ...            ...         ...        ...
# 18534   21            174             68        1287        274
# 18535   17            175             60        1289        267
# 18536   18            170             65        1333        277
# 18537   17            178             65        1113        226
# 18538   25            176             66        1277        269
#
#                  Club Name  Wage(in Euro)  Release Clause Club Position  \
# 130         Leicester City         115000       103700000            CM
# ...

# %% [markdown]
# ### 5. Tampilkan jumlah label dari semua attribute yang bernilai object.

# %%
fifa = pd.read_csv('Fifa 23 Players Data.csv')
objek = fifa.select_dtypes(include=['object'])
jumlah_objek = objek.nunique()

tabel = pd.DataFrame({
    'Nama Atribut': jumlah_objek.index, 
    'Total Nilai': jumlah_objek.values})

print(tabel)
# Out:
#                    Nama Atribut  Total Nilai
# 0                      Known As        17530
# 1                     Full Name        18337
# 2              Positions Played          693
# 3                 Best Position           15
# 4                   Nationality          160
# 5                    Image Link        18420
# 6                     Club Name          679
# 7                 Club Position           20
# 8                Contract Until           10
# 9            Club Jersey Number          100
# 10                      On Loan            2
# 11               Preferred Foot            2
# 12           National Team Name           36
# 13     National Team Image Link           48
# 14       National Team Position           18
# 15  National Team Jersey Number           29
# 16          Attacking Work Rate            3
# 17          Defensive Work Rate            3
