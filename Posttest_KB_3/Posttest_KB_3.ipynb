# %% [markdown]
# # POSTTEST 3

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df_fifa = pd.read_csv('Fifa 23 Players Data.csv')
df_fifa.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %% [markdown]
# ### 1. Pie Chart

# %% [markdown]
# Grafik dibawah menunjukkan bahwa pemain yang memiliki kaki terkuat sebelah kanan ada sebanyak 75.8% sedangakan pemain yang memiliki kaki terkuat sebelah kiri sebanyak 24.2%

# %%
data_pie = fifa['Preferred Foot'].value_counts().rename('Preferred Foot').reset_index(name='Player') 
data_pie
# Out:
#    index  Player
# 0  Right   14045
# 1   Left    4494

# %%
x = list(df["Known As"])
y = list(df["Preferred Foot"])

data_pie = df['Preferred Foot'].value_counts().rename_axis('Preferred Foot').reset_index(name='Known As')
colors = ['orange', 'blue']

plt.figure(figsize=(5,5))
plt.pie(data_pie['Known As'], labels=data_pie['Preferred Foot'], startangle=90, autopct='%.1f%%', explode=(0.1, 0), shadow=True, colors=colors)
plt.title('Kaki terkuat dari pemain')
plt.show()

# %% [markdown]
# ### 4. Heatmap

# %% [markdown]
# Dari heatmap korelasi antara variabel numerik dalam dataset Fifa Players, dapat diambil kesimpulan bahwa terdapat beberapa hubungan yang signifikan antara variabel-variabel tersebut.

# %%
correlation_matrix = df_fifa.corr()
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='bone')
plt.title('Heatmap Korelasai Antara Variabel Numerik')
plt.xlabel('Variabel')
plt.ylabel('Variabel')
plt.show()
# Out:
# C:\Users\NITRO 5\AppData\Local\Temp\ipykernel_6816\2319258091.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_fifa.corr()

# %% [markdown]
# ### 3. Bar Chart

# %% [markdown]
# Bar chart yang memvisualisasikan jumlah pemain dalam setiap negaranya. Setiap batang pada chart mewakili satu negara, dan tinggi batang tersebut menunjukkan jumlah pemain dalam negara tersebut.

# %%
league_counts = df['Nationality'].value_counts()
plt.figure(figsize=(30, 10))
league_counts.plot(kind='bar', color='skyblue')
plt.title('Jumlah Pemain dalam Setiap Negara')
plt.xlabel('Negara')
plt.ylabel('Jumlah Pemain')
plt.show()

# %% [markdown]
# ### 4. Grafik Batang

# %% [markdown]
# Grafik batang ini menunjukkan umur dari pemain dan Overall yang didapatkan pada umur tersebut.

# %%
x = list(df_fifa["Overall"])
y = list(df_fifa["Age"])

plt.figure(figsize =(7, 10))
plt.bar(x, y, color='blue')
plt.xlabel("Overall")
plt.ylabel("Age")
plt.title("umur dan pekerjaan pelanggan")
plt.show()
